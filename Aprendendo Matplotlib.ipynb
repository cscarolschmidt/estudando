# %% [markdown]
# ## Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot(); 

#colocamos o ponto e vírgula pra tirar os colchetes vazios ali de cima

# %%
plt.plot()
plt.show()

#pode ser assim também pra tirar os colchetes.

# %%
plt.plot([1,2,3,4]);

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y);

# %%
# 1st method
fig = plt.figure() #creates a figure
ax = fig.add_subplot() # adds some axes
plt.show()

# %%
# 2nd method
fig = plt.figure() #create a figure
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)  #add some data
plt.show()

# %%
# 3rd method (recommended)
fig, ax = plt.subplots()
ax.plot(x,y); #add some data

# %%
fig, ax = plt.subplots()
ax.plot(x,[50,100,200,250]);
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ## Matplotlib Example Workflow
#
# We want:
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplots

# %%
# 0. Import Matplotlib and get it ready for plotting in Jupyter (já fizemos no início)

# 1. Prepare data
x = [1,2,3,4]
y = [11,22,33,44]

# 2. Setup a plot
fig, ax = plt.subplots(figsize=(10,10)) #figsize=(largura,altura) ou (x,y)

# 3. Plot the data
ax.plot(x,y)

# 4. Customize the plot
ax.set(title='Simple plot',
       xlabel='x-axis',
       ylabel='y-axis')

# 5. Save & show (you save the whole figure)
#fig.savefig('..images/sample-plot.png')
# Out:
# [Text(0.5, 1.0, 'Simple plot'), Text(0.5, 0, 'x-axis'), Text(0, 0.5, 'y-axis')]

# %% [markdown]
# ## Making Figures with Numpy Arrays

# %%
# Create some data
x = np.linspace(0,10,100) # começa em 0, vai até 10, 100 números.
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
# Plot the data and create a line plot
fig, ax = plt.subplots()
ax.plot(x, x**2); #plot faz gráficos de linha

# %%
# Use same data to make a scatter (gráfico feito de bolinhas)
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x)); #np.exp = exponencial

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x)); #sign wave

# %%
# Make a bar plot from dictionary
nutbutterprices = {'Almond butter':10,
                   'Peanut butter':8,
                   'Cashew butter':12}
fig,ax = plt.subplots()
ax.bar(nutbutterprices.keys(), nutbutterprices.values())
ax.set(title= "Dan's Nut Butter Store",
       ylabel = 'Price ($)');

# %%
fig,ax = plt.subplots()
ax.barh(list(nutbutterprices.keys()), list(nutbutterprices.values())) #gráfico de barras na horizontal
ax.set(title= "Dan's Nut Butter Store",
       xlabel = 'Price ($)');

# %%
# Make some data for histogram and plot it
x = np.random.randn(1000) 

# vai criar 1000 números que formam uma curva de distribuição normal, que tem como meio a média e a distância 
# da curva pra cada lado é a variância.

fig,ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Two options for subplots

# %%
# Subplots Option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2,
                                             ncols = 2,
                                             figsize = (10,5))
# Plot to each different axis
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nutbutterprices.keys(), nutbutterprices.values());
ax4.hist(np.random.randn(1000));

# %%
# Subplots Option 2
fig, ax = plt.subplots(nrows = 2,
                       ncols = 2,
                       figsize = (10,5))
# Plot to each different axis
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10), np.random.random(10));
ax[1,0].bar(nutbutterprices.keys(), nutbutterprices.values());
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from Pandas DataFrames

# %%
# Make a dataframe

ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2020', periods=1000))
ts = ts.cumsum() #soma cumulativa
ts.plot()

# exemplo da internet
# Out:
# <AxesSubplot:>

# %%
carsales = pd.read_csv('car-sales.csv')
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
carsales['Price'] = carsales['Price'].str.replace('[$\,\.]', '') #remove símbolos
carsales['Price'] = carsales['Price'].str[:-2] #remove last two zeros
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
carsales['Sale Date'] = pd.date_range('1/1/2020', periods=len(carsales))
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
carsales['Total Sales']=carsales['Price'].astype(int).cumsum()
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
# Let's plot the total sales
carsales.plot(x='Sale Date', y='Total Sales');

# %%
carsales['Price'] = carsales['Price'].astype(int)
carsales.plot(x='Odometer (KM)', y='Price', kind='scatter');

# %%
#How about a bar graph
x= np.random.rand(10,4)

df = pd.DataFrame(x, columns=['a','b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.809631  0.574508  0.791137  0.294572
# 1  0.100953  0.395842  0.798917  0.262417
# 2  0.965444  0.129252  0.296323  0.203126
# 3  0.030517  0.307702  0.050677  0.352768
# 4  0.966531  0.141798  0.057344  0.419661
# 5  0.663347  0.745806  0.635782  0.829833
# 6  0.304571  0.861352  0.039045  0.684374
# 7  0.148910  0.726211  0.049741  0.669375
# 8  0.461928  0.403159  0.661000  0.804169
# 9  0.216283  0.501803  0.155033  0.262780

# %%
df.plot.bar();

# %%
df.plot(kind='bar');

# %%
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
carsales.plot(x='Make', y='Odometer (KM)', kind='bar');

# %%
# How about histograms
# são bons para visualizar distribuição

carsales['Odometer (KM)'].plot.hist();

# %%
carsales['Odometer (KM)'].plot.hist(bins=20); 

#bins é o número de barrinhas do histogram, mais bins deixa as barrinhas mais magrinhas pra caber mais.

# %%
# Let's try on another dataset
heartdisease = pd.read_csv('heart-disease.csv')
heartdisease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heartdisease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Create a histrogram of age
heartdisease['age'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
heartdisease.plot.hist(subplots=True)
# Out:
# array([<AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>],
#       dtype=object)

# %% [markdown]
# ### Which one should you use? (pyplot vs matplotlib OO method?)
#
#
# * When plotting something quickly it's ok to use the pyplot method;
# * When plotting something more advanced use the OO method.

# %%
over50 = heartdisease[heartdisease['age']>50]
over50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
len(over50)
# Out:
# 208

# %%
#Pyplot method

over50.plot(kind='scatter',
            x='age',
            y='chol',
            c='target');

# c is short for color.

# %%
# OO method mixed with Pyplot method

fig, ax = plt.subplots(figsize=(10,6))
over50.plot(kind='scatter',
            x='age',
            y='chol',
            c='target',
            ax=ax);
#ax.set_xlim([45,100]); usando isso fica com mais espaço no gráfico, mas pro nosso não precisa.

# %%
# OO method from scracth
fig, ax = plt.subplots(figsize=(10,6))

#Plot the data
scatter= ax.scatter(x= over50['age'],
                    y=over50['chol'],
                    c=over50['target'])

#Custumize the plot
ax.set(title='Heart Disease and Cholesterol Levels',
       xlabel='Age',
       ylabel='Cholesterol');

# Add a legend
ax.legend(*scatter.legend_elements(), title='Target');

# Add a horizontal line
ax.axhline(over50['chol'].mean(),
           linestyle='--');

# %%
over50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Subplot of chol, age, thalach (máxima frequência cardíaca)
fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10,10))

# Add data to ax0
scatter= ax0.scatter(x= over50['age'],
                     y=over50['chol'],
                     c=over50['target'])

# Customize ax0
ax0.set(title='Heart Disease and Cholesterol Levels',
       xlabel='Age',
       ylabel='Cholesterol');

# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title='Target');

# Add a mean line
ax0.axhline(y=over50['chol'].mean(),
            linestyle='--');

# Add data to ax1
scatter= ax1.scatter(x= over50['age'],
                     y=over50['thalach'],
                     c=over50['target'])

# Customize ax1
ax1.set(title='Heart Disease and Max Heart Rate',
       xlabel='Age',
       ylabel='Max Heart Rate');

# Add a legend to ax1
ax1.legend(*scatter.legend_elements(), title='Target');

# Add a mean line
ax1.axhline(y=over50['thalach'].mean(),
            linestyle='--');

# %%
#Mesmos gráfico de cima, mas compartilhando o eixo x e com um título grande pra figura toda.

# Subplot of chol, age, thalach (máxima frequência cardíaca)
fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10,10),
                               sharex=True)

# Add data to ax0
scatter= ax0.scatter(x= over50['age'],
                     y=over50['chol'],
                     c=over50['target'])

# Customize ax0
ax0.set(title='Heart Disease and Cholesterol Levels',
       ylabel='Cholesterol');

# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title='Target');

# Add a mean line
ax0.axhline(y=over50['chol'].mean(),
            linestyle='--');

# Add data to ax1
scatter= ax1.scatter(x= over50['age'],
                     y=over50['thalach'],
                     c=over50['target'])

# Customize ax1
ax1.set(title='Heart Disease and Max Heart Rate',
       xlabel='Age',
       ylabel='Max Heart Rate');

# Add a legend to ax1
ax1.legend(*scatter.legend_elements(), title='Target');

# Add a mean line
ax1.axhline(y=over50['thalach'].mean(),
            linestyle='--');

# Add a title to the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');

# %% [markdown]
# ## Customizing Matplotlib plots and Getting Stylish

# %%
# See the different styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
carsales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500

# %%
carsales['Price'].plot();

# %%
plt.style.use('seaborn-whitegrid') #assim mudamos o estilo padrão de criação de gráficos.

# %%
carsales['Price'].plot();

# %%
plt.style.use('seaborn')

# %%
carsales['Price'].plot();

# %%
#Create some data
x = np.random.randn(10,4)
x
# Out:
# array([[ 0.34717129,  1.01520805, -0.78005889, -1.71838888],
#        [ 0.25955915,  1.47873924,  0.31960943, -0.60931793],
#        [-0.99826125, -0.09898114,  0.09757545, -0.38646375],
#        [-1.11370948, -0.44970031, -0.64719181,  0.79095016],
#        [-2.17425566, -0.2297187 , -0.43836361, -0.23309899],
#        [-0.64147701, -1.14940865,  1.12372262, -1.37000255],
#        [-0.21220073,  1.45031622,  1.27937411, -0.05556292],
#        [-0.73339153,  1.76707965,  1.59508862,  1.17982989],
#        [ 0.26834309,  0.18998821,  1.03423272, -0.24305648],
#        [-1.31029894,  0.26686312, -1.33713295,  0.69399664]])

# %%
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.347171  1.015208 -0.780059 -1.718389
# 1  0.259559  1.478739  0.319609 -0.609318
# 2 -0.998261 -0.098981  0.097575 -0.386464
# 3 -1.113709 -0.449700 -0.647192  0.790950
# 4 -2.174256 -0.229719 -0.438364 -0.233099
# 5 -0.641477 -1.149409  1.123723 -1.370003
# 6 -0.212201  1.450316  1.279374 -0.055563
# 7 -0.733392  1.767080  1.595089  1.179830
# 8  0.268343  0.189988  1.034233 -0.243056
# 9 -1.310299  0.266863 -1.337133  0.693997

# %%
ax = df.plot(kind='bar')

# %%
# Customize our plot with the set() method
ax = df.plot(kind='bar')

# Add some labels and a title
ax.set(title='Random Number bar Graph fom DataFrame',
       xlabel='Row Number',
       ylabel='Random Number')

# Make the legend visible
ax.legend().set_visible(True)

# %%
#Set the style
plt.style.use('seaborn-whitegrid')

# OO method from scracth
fig, ax = plt.subplots(figsize=(10,6))

#Plot the data
scatter= ax.scatter(x= over50['age'],
                    y=over50['chol'],
                    c=over50['target'],
                    cmap='winter') #this changes the colour scheme

#Custumize the plot
ax.set(title='Heart Disease and Cholesterol Levels',
       xlabel='Age',
       ylabel='Cholesterol');

# Add a legend
ax.legend(*scatter.legend_elements(), title='Target');

# Add a horizontal line
ax.axhline(over50['chol'].mean(),
           linestyle='--');

# %%
# Customizing the y and x axis limitations
mudamos os limites dos gráficos para tirar as linhas indesejadas.

# Subplot of chol, age, thalach (máxima frequência cardíaca)
fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10,10),
                               sharex=True)

# Add data to ax0
scatter= ax0.scatter(x= over50['age'],
                     y=over50['chol'],
                     c=over50['target'],
                     cmap='winter')

# Customize ax0
ax0.set(title='Heart Disease and Cholesterol Levels',
       ylabel='Cholesterol');

#Change the x axis limits
ax0.set_xlim([50,80])

# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title='Target');

# Add a mean line
ax0.axhline(y=over50['chol'].mean(),
            linestyle='--');

# Add data to ax1
scatter= ax1.scatter(x= over50['age'],
                     y=over50['thalach'],
                     c=over50['target'],
                     cmap='winter')

# Customize ax1
ax1.set(title='Heart Disease and Max Heart Rate',
       xlabel='Age',
       ylabel='Max Heart Rate');

#Change the x and y axis limits
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])

# Add a legend to ax1
ax1.legend(*scatter.legend_elements(), title='Target');

# Add a mean line
ax1.axhline(y=over50['thalach'].mean(),
            linestyle='--');

# Add a title to the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');

# %%
# Saving the figure

fig.savefig('heart-disease-analysis-plot.png')
